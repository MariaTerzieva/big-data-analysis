# %% [markdown]
# # Imports and Initial Setup

# %%
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.sql.types import StructField, StructType, DateType, TimestampType, StringType, IntegerType, FloatType
import pyspark.sql.functions as f
from PySparkAudit import counts, describe, freq_items, corr_matrix

# %%
sc = SparkContext('local')
spark = SparkSession(sc)

# %% [markdown]
# # Load Data

# %% [markdown]
# ### NYC Citi Bike Trip Data (February 2016)

# %% [markdown]
# The data includes:
#
# * Trip Duration (seconds)
# * Start Time and Date
# * Stop Time and Date
# * Start Station Name
# * End Station Name
# * Station ID
# * Station Lat/Long
# * Bike ID
# * User Type (Customer = 24-hour pass or 3-day pass user; Subscriber = Annual Member)
# * Gender (0=unknown; 1=male; 2=female)
# * Year of Birth

# %%
citibike_schema = StructType([
    StructField('Trip Duration', IntegerType(), nullable=True),
    StructField('Start Time', TimestampType(), nullable=True),
    StructField('Stop Time', TimestampType(), nullable=True),
    StructField('Start Station ID', IntegerType(), nullable=True),
    StructField('Start Station Name', StringType(), nullable=True),
    StructField('Start Station Latitude', FloatType(), nullable=True),
    StructField('Start Station Longtitude', FloatType(), nullable=True),
    StructField('End Station ID', IntegerType(), nullable=True),
    StructField('End Station Name', StringType(), nullable=True),
    StructField('End Station Latitude', FloatType(), nullable=True),
    StructField('End Station Longtitude', FloatType(), nullable=True),
    StructField('Bike ID', IntegerType(), nullable=True),
    StructField('User Type', StringType(), nullable=True),
    StructField('Birth Year', IntegerType(), nullable=True),
    StructField('Gender', IntegerType(), nullable=True)
])

# %%
citibike_df = spark.read.csv('JC-20162-citibike-tripdata.csv', header='true', schema=citibike_schema, timestampFormat="yyyy-MM-dd HH:mm:ss", ignoreLeadingWhiteSpace='true', ignoreTrailingWhiteSpace='true')

# %%
citibike_df.limit(5).toPandas()
# Out:
#    Trip Duration          Start Time           Stop Time  Start Station ID  \
# 0            361 2016-02-01 00:31:18 2016-02-01 00:37:19              3202
# 1            297 2016-02-01 01:55:05 2016-02-01 02:00:02              3195
# 2           1155 2016-02-01 02:40:05 2016-02-01 02:59:20              3183
# 3           1769 2016-02-01 05:11:28 2016-02-01 05:40:58              3214
# 4            935 2016-02-01 05:48:24 2016-02-01 06:03:59              3203
#
#   Start Station Name  Start Station Latitude  Start Station Longtitude  \
# 0       Newport PATH               40.727222                -74.033760
# 1            Sip Ave               40.730743                -74.063782
# 2     Exchange Place               40.716248                -74.033463
# 3   Essex Light Rail               40.712772                -74.036484
# 4      Hamilton Park               40.727596                -74.044250
#
#    End Station ID  End Station Name  End Station Latitude  \
# 0            3203     Hamilton Park             40.727596
# 1            3194   McGinley Square             40.725342
# 2            3210    Pershing Field             40.742676
# 3            3203     Hamilton Park             40.727596
# 4            3214  Essex Light Rail             40.712772
#
#    End Station Longtitude  Bike ID   User Type  Birth Year  Gender
# 0              -74.044250    24393  Subscriber        1975       1
# 1              -74.067619    24394  Subscriber        1985       2
# 2              -74.051788    24676  Subscriber        1976       1
# 3              -74.044250    24700  Subscriber        1974       2
# 4              -74.036484    24639  Subscriber        1974       2

# %% [markdown]
# ### NYC Weather Data (2016)

# %% [markdown]
# The data includes:
#
# * Daily maximum, minimum and average temperature (degrees F)
# * Daily precipitation, snowfall and snow depth (inches; T means trace, not enough for a value)

# %%
weather_schema = StructType([
    StructField('date', DateType(), nullable=True),
    StructField('maximum temperature', IntegerType(), nullable=True),
    StructField('minimum temperature', IntegerType(), nullable=True),
    StructField('average temperature', FloatType(), nullable=True),
    StructField('precipitation', StringType(), nullable=True),
    StructField('snow fall', StringType(), nullable=True),
    StructField('snow depth', StringType(), nullable=True)
])

# %%
weather_df = spark.read.csv('weather_data_nyc_centralpark_2016(1).csv', header='true', schema=weather_schema, dateFormat='dd-MM-yyyy', ignoreLeadingWhiteSpace='true', ignoreTrailingWhiteSpace='true')

# %%
weather_df.limit(5).toPandas()
# Out:
#          date  maximum temperature  minimum temperature  average temperature  \
# 0  2016-01-01                   42                   34                 38.0
# 1  2016-01-02                   40                   32                 36.0
# 2  2016-01-03                   45                   35                 40.0
# 3  2016-01-04                   36                   14                 25.0
# 4  2016-01-05                   29                   11                 20.0
#
#   precipitation snow fall snow depth
# 0          0.00       0.0          0
# 1          0.00       0.0          0
# 2          0.00       0.0          0
# 3          0.00       0.0          0
# 4          0.00       0.0          0

# %% [markdown]
# # Data Checks and Validation

# %% [markdown]
# ### NYC Citi Bike Trip Data (February 2016)

# %% [markdown]
# Check if User Type has values Subscriber or Customer only:

# %%
citibike_df.where((f.col('User Type') != 'Subscriber') & (f.col('User Type') != 'Customer')).count() == 0
# Out:
# True

# %% [markdown]
# Check if Gender has values 0, 1 or 2 only:

# %%
citibike_df.where((f.col('Gender') != 0) & (f.col('Gender') != 1) & (f.col('Gender') != 2)).count() == 0
# Out:
# True

# %% [markdown]
# Check if all data is just for February 2016:

# %%
citibike_df.where(~(f.col('Start Time').like('2016-02%') | f.col('Stop Time').like('2016-02%'))).count() == 0
# Out:
# True

# %% [markdown]
# ### NYC Weather Data (2016)

# %% [markdown]
# Check if all data is just from 2016:

# %%
weather_df.where(~f.col('date').like('2016%')).count() == 0
# Out:
# True

# %% [markdown]
# # Data Prep

# %% [markdown]
# ### NYC Citi Bike Trip Data (February 2016)

# %% [markdown]
# Split Start Time and Stop Time into Start Day and Start Time and Stop Day and Stop Time:

# %%
split_start = f.split(citibike_df['Start Time'], ' ')
split_stop = f.split(citibike_df['Stop Time'], ' ')

# %%
citibike_df = citibike_df.withColumn('Start Day', split_start.getItem(0))
citibike_df = citibike_df.withColumn('Start Time', split_start.getItem(1))
citibike_df = citibike_df.withColumn('Stop Day', split_stop.getItem(0))
citibike_df = citibike_df.withColumn('Stop Time', split_stop.getItem(1))

# %%
citibike_df.limit(5).toPandas()
# Out:
#    Trip Duration Start Time Stop Time  Start Station ID Start Station Name  \
# 0            361   00:31:18  00:37:19              3202       Newport PATH
# 1            297   01:55:05  02:00:02              3195            Sip Ave
# 2           1155   02:40:05  02:59:20              3183     Exchange Place
# 3           1769   05:11:28  05:40:58              3214   Essex Light Rail
# 4            935   05:48:24  06:03:59              3203      Hamilton Park
#
#    Start Station Latitude  Start Station Longtitude  End Station ID  \
# 0               40.727222                -74.033760            3203
# 1               40.730743                -74.063782            3194
# 2               40.716248                -74.033463            3210
# 3               40.712772                -74.036484            3203
# 4               40.727596                -74.044250            3214
#
#    End Station Name  End Station Latitude  End Station Longtitude  Bike ID  \
# 0     Hamilton Park             40.727596              -74.044250    24393
# 1   McGinley Square             40.725342              -74.067619    24394
# 2    Pershing Field             40.742676              -74.051788    24676
# 3     Hamilton Park             40.727596              -74.044250    24700
# 4  Essex Light Rail             40.712772              -74.036484    24639
#
#     User Type  Birth Year  Gender   Start Day    Stop Day
# 0  Subscriber        1975       1  2016-02-01  2016-02-01
# 1  Subscriber        1985       2  2016-02-01  2016-02-01
# 2  Subscriber        1976       1  2016-02-01  2016-02-01
# 3  Subscriber        1974       2  2016-02-01  2016-02-01
# 4  Subscriber        1974       2  2016-02-01  2016-02-01

# %% [markdown]
# ### NYC Weather Data (2016)

# %% [markdown]
# Filter weather data to include records only for February 2016:

# %%
weather_df = weather_df.where(f.col('date').between('2016-02-01', '2016-02-29'))

# %%
weather_df.count() == 29
# Out:
# True

# %%
weather_df.limit(5).toPandas()
# Out:
#          date  maximum temperature  minimum temperature  average temperature  \
# 0  2016-02-01                   59                   44                 51.5
# 1  2016-02-02                   50                   38                 44.0
# 2  2016-02-03                   59                   42                 50.5
# 3  2016-02-04                   59                   44                 51.5
# 4  2016-02-05                   44                   31                 37.5
#
#   precipitation snow fall snow depth
# 0          0.01       0.0          2
# 1          0.00       0.0          T
# 2          0.73       0.0          0
# 3             T       0.0          0
# 4          0.53       2.5          1

# %% [markdown]
# 0.00 < T < 0.01. Let's round up Ts to 0.01 so that the last three columns are all numeric:

# %%
weather_df = weather_df.withColumn('precipitation', f.when(f.col('precipitation') == 'T', 0.01).otherwise(f.col('precipitation')).cast(FloatType()))
weather_df = weather_df.withColumn('snow fall', f.when(f.col('snow fall') == 'T', 0.01).otherwise(f.col('snow fall')).cast(FloatType()))
weather_df = weather_df.withColumn('snow depth', f.when(f.col('snow depth') == 'T', 0.01).otherwise(f.col('snow depth')).cast(IntegerType()))

# %%
weather_df.limit(5).toPandas()
# Out:
#          date  maximum temperature  minimum temperature  average temperature  \
# 0  2016-02-01                   59                   44                 51.5
# 1  2016-02-02                   50                   38                 44.0
# 2  2016-02-03                   59                   42                 50.5
# 3  2016-02-04                   59                   44                 51.5
# 4  2016-02-05                   44                   31                 37.5
#
#    precipitation  snow fall  snow depth
# 0           0.01        0.0           2
# 1           0.00        0.0           0
# 2           0.73        0.0           0
# 3           0.01        0.0           0
# 4           0.53        2.5           1

# %% [markdown]
# # Join The Two Datasets

# %%
full_df = citibike_df.join(weather_df, citibike_df['Start Day'] == weather_df['date'], how='inner').drop('date')

# %%
full_df.limit(5).toPandas()
# Out:
#    Trip Duration Start Time Stop Time  Start Station ID Start Station Name  \
# 0            361   00:31:18  00:37:19              3202       Newport PATH
# 1            297   01:55:05  02:00:02              3195            Sip Ave
# 2           1155   02:40:05  02:59:20              3183     Exchange Place
# 3           1769   05:11:28  05:40:58              3214   Essex Light Rail
# 4            935   05:48:24  06:03:59              3203      Hamilton Park
#
#    Start Station Latitude  Start Station Longtitude  End Station ID  \
# 0               40.727222                -74.033760            3203
# 1               40.730743                -74.063782            3194
# 2               40.716248                -74.033463            3210
# 3               40.712772                -74.036484            3203
# 4               40.727596                -74.044250            3214
#
#    End Station Name  End Station Latitude  ...  Birth Year  Gender  \
# 0     Hamilton Park             40.727596  ...        1975       1
# 1   McGinley Square             40.725342  ...        1985       2
# 2    Pershing Field             40.742676  ...        1976       1
# 3     Hamilton Park             40.727596  ...        1974       2
# 4  Essex Light Rail             40.712772  ...        1974       2
#
#     Start Day    Stop Day  maximum temperature minimum temperature  \
# 0  2016-02-01  2016-02-01                   59                  44
# 1  2016-02-01  2016-02-01                   59                  44
# 2  2016-02-01  2016-02-01                   59                  44
# 3  2016-02-01  2016-02-01                   59                  44
# 4  2016-02-01  2016-02-01                   59                  44
#
#   average temperature  precipitation  snow fall  snow depth
# 0                51.5           0.01        0.0           2
# 1                51.5           0.01        0.0           2
# 2                51.5           0.01        0.0           2
# 3                51.5           0.01        0.0           2
# 4                51.5           0.01        0.0           2
#
# [5 rows x 23 columns]

# %% [markdown]
# # Analysis and Visualization

# %% [markdown]
# Count notnull and distinct values:

# %%
counts(full_df)
# Out:
#                      feature  row_count  notnull_count  distinct_count
# 0              Trip Duration       8250           8250            1571
# 1                 Start Time       8250           8250            7586
# 2                  Stop Time       8250           8250            7587
# 3           Start Station ID       8250           8250              35
# 4         Start Station Name       8250           8250              35
# 5     Start Station Latitude       8250           8250              35
# 6   Start Station Longtitude       8250           8250              35
# 7             End Station ID       8250           8250              39
# 8           End Station Name       8250           8250              39
# 9       End Station Latitude       8250           8250              39
# 10    End Station Longtitude       8250           8250              39
# 11                   Bike ID       8250           8250             254
# 12                 User Type       8250           8250               2
# 13                Birth Year       8250           7920              52
# 14                    Gender       8250           8250               3
# 15                 Start Day       8250           8250              29
# 16                  Stop Day       8250           8250              31
# 17       maximum temperature       8250           8250              18
# 18       minimum temperature       8250           8250              20
# 19       average temperature       8250           8250              22
# 20             precipitation       8250           8250              11
# 21                 snow fall       8250           8250               5
# 22                snow depth       8250           8250               3

# %% [markdown]
# Calculate distinct count, min, mean, max and standard deviation for columns for which this information is valuable:

# %%
describe(full_df[['Trip Duration', 'Start Time', 'Stop Time', 'Start Day', 'Stop Day', 'Birth Year', 'maximum temperature', 'minimum temperature', 'average temperature', 'precipitation', 'snow fall', 'snow depth']])
# Out:
# summary             count                 mean              stddev  \
# feature
# Trip Duration        8250             1424.132   40051.95339126977
# Start Time           8250                 None                None
# Stop Time            8250                 None                None
# Start Day            8250                 None                None
# Stop Day             8250                 None                None
# Birth Year           7920   1978.8729797979797   9.535096889682688
# maximum temperature  8250    47.38363636363636  11.041830727297498
# minimum temperature  8250    33.46787878787879   8.927544634661732
# average temperature  8250    40.42575757575757   9.706067981896194
# precipitation        8250  0.11077575829579975  0.2734341007857553
# snow fall            8250  0.07416363612381797  0.3880846647867171
# snow depth           8250  0.10751515151515152  0.4266594836877959
#
# summary                     min         max
# feature
# Trip Duration                61     2104123
# Start Time             00:01:01    23:59:41
# Stop Time              00:01:21    23:59:18
# Start Day            2016-02-01  2016-02-29
# Stop Day             2016-02-01  2016-03-07
# Birth Year                 1947        1999
# maximum temperature          15          61
# minimum temperature          -1          47
# average temperature         7.0        54.0
# precipitation               0.0        1.22
# snow fall                   0.0         2.5
# snow depth                    0           2

# %% [markdown]
# Find most popular values and the number of times they occur:

# %%
freq_items(full_df)
# Out:
#                      feature  \
# 0              Trip Duration
# 1                 Start Time
# 2                  Stop Time
# 3           Start Station ID
# 4         Start Station Name
# 5     Start Station Latitude
# 6   Start Station Longtitude
# 7             End Station ID
# 8           End Station Name
# 9       End Station Latitude
# 10    End Station Longtitude
# 11                   Bike ID
# 12                 User Type
# 13                Birth Year
# 14                    Gender
# 15                 Start Day
# 16                  Stop Day
# 17       maximum temperature
# 18       minimum temperature
# 19       average temperature
# 20             precipitation
# 21                 snow fall
# 22                snow depth
#
#                               freq_items[value, freq]
# 0   [[305, 32], [150, 30], [242, 29], [245, 27], [...
# 1   [[17:34:19, 4], [17:52:32, 4], [09:02:53, 3], ...
# 2   [[09:12:47, 4], [13:04:29, 4], [09:07:34, 4], ...
# 3   [[3186, 998], [3195, 717], [3203, 682], [3209,...
# 4   [[Grove St PATH, 998], [Sip Ave, 717], [Hamilt...
# 5   [[40.71958541870117, 998], [40.730743408203125...
# 6   [[-74.0431137084961, 998], [-74.06378173828125...
# 7   [[3186, 1440], [3195, 661], [3203, 624], [3183...
# 8   [[Grove St PATH, 1440], [Sip Ave, 661], [Hamil...
# 9   [[40.71958541870117, 1440], [40.73074340820312...
# 10  [[-74.0431137084961, 1440], [-74.0637817382812...
# 11  [[24419, 68], [24574, 66], [24412, 61], [24498...
# 12              [[Subscriber, 7920], [Customer, 330]]
# 13  [[1984, 536], [1981, 507], [1977, 397], [1983,...
# 14                   [[1, 6283], [2, 1629], [0, 338]]
# 15  [[2016-02-22, 437], [2016-02-28, 417], [2016-0...
# 16  [[2016-02-22, 436], [2016-02-28, 413], [2016-0...
# 17  [[39, 1636], [61, 1119], [59, 1000], [36, 637]...
# 18  [[38, 1265], [44, 1037], [27, 982], [35, 870],...
# 19  [[31.5, 967], [49.0, 789], [51.5, 733], [33.5,...
# 20  [[0.0, 4338], [0.009999999776482582, 1306], [0...
# 21  [[0.0, 6514], [0.009999999776482582, 1165], [0...
# 22                    [[0, 7718], [2, 355], [1, 177]]

# %% [markdown]
# Calculate correlations between variables:

# %%
corr_matrix(full_df)
# Out:
# ================================================================
# The correlation matrix plot Corr.png was located at:
# /home/maria/Kaufland IT Hub/Audited
#                           Trip Duration  Start Station ID  \
# Trip Duration                  1.000000         -0.010974
# Start Station ID              -0.010974          1.000000
# Start Station Latitude        -0.023682          0.304295
# Start Station Longtitude       0.022613         -0.174111
# End Station ID                -0.003260         -0.003534
# End Station Latitude          -0.019980          0.052183
# End Station Longtitude         0.018810          0.042294
# Bike ID                        0.011278         -0.011723
# Birth Year                    -0.007287         -0.001169
# Gender                         0.007325         -0.008885
# maximum temperature           -0.034607         -0.010285
# minimum temperature           -0.038832         -0.010587
# average temperature           -0.037542         -0.010718
# precipitation                 -0.007900         -0.006927
# snow fall                     -0.003725         -0.020095
# snow depth                    -0.005250         -0.017990
#
#                           Start Station Latitude  Start Station Longtitude  \
# Trip Duration                          -0.023682                  0.022613
# Start Station ID                        0.304295                 -0.174111
# Start Station Latitude                  1.000000                 -0.277670
# Start Station Longtitude               -0.277670                  1.000000
# End Station ID                          0.033522                 -0.026737
# End Station Latitude                    0.474659                 -0.296585
# End Station Longtitude                 -0.285721                  0.577937
# Bike ID                                -0.001922                  0.004986
# Birth Year                             -0.018184                 -0.007831
# Gender                                 -0.080182                  0.044079
# maximum temperature                    -0.004869                  0.026674
# minimum temperature                    -0.001759                  0.030763
# average temperature                    -0.003576                  0.029320
# precipitation                           0.008255                 -0.010111
# snow fall                              -0.004970                  0.003085
# snow depth                              0.010520                  0.023392
#
#                           End Station ID  End Station Latitude  \
# Trip Duration                  -0.003260             -0.019980
# Start Station ID               -0.003534              0.052183
# Start Station Latitude          0.033522              0.474659
# Start Station Longtitude       -0.026737             -0.296585
# End Station ID                  1.000000              0.063775
# End Station Latitude            0.063775              1.000000
# End Station Longtitude         -0.108479             -0.304102
# Bike ID                        -0.003683             -0.001966
# Birth Year                     -0.005745             -0.037745
# Gender                          0.013348             -0.071937
# maximum temperature             0.006642             -0.015206
# minimum temperature             0.003715             -0.015288
# average temperature             0.005484             -0.015678
# precipitation                  -0.000807             -0.003269
# snow fall                      -0.024681              0.009392
# snow depth                     -0.004568              0.005592
#
#                           End Station Longtitude   Bike ID  Birth Year  \
# Trip Duration                           0.018810  0.011278   -0.007287
# Start Station ID                        0.042294 -0.011723   -0.001169
# Start Station Latitude                 -0.285721 -0.001922   -0.018184
# Start Station Longtitude                0.577937  0.004986   -0.007831
# End Station ID                         -0.108479 -0.003683   -0.005745
# End Station Latitude                   -0.304102 -0.001966   -0.037745
# End Station Longtitude                  1.000000 -0.002618    0.003584
# Bike ID                                -0.002618  1.000000    0.002476
# Birth Year                              0.003584  0.002476    1.000000
# Gender                                  0.047291 -0.009654    0.082169
# maximum temperature                     0.016503 -0.005124    0.007298
# minimum temperature                     0.019180 -0.013448   -0.000337
# average temperature                     0.018208 -0.009104    0.003990
# precipitation                          -0.013085  0.012072   -0.005175
# snow fall                              -0.005575  0.018574    0.004706
# snow depth                              0.008409  0.013145   -0.008337
#
#                             Gender  maximum temperature  minimum temperature  \
# Trip Duration             0.007325            -0.034607            -0.038832
# Start Station ID         -0.008885            -0.010285            -0.010587
# Start Station Latitude   -0.080182            -0.004869            -0.001759
# Start Station Longtitude  0.044079             0.026674             0.030763
# End Station ID            0.013348             0.006642             0.003715
# End Station Latitude     -0.071937            -0.015206            -0.015288
# End Station Longtitude    0.047291             0.016503             0.019180
# Bike ID                  -0.009654            -0.005124            -0.013448
# Birth Year                0.082169             0.007298            -0.000337
# Gender                    1.000000             0.022724             0.021069
# maximum temperature       0.022724             1.000000             0.889160
# minimum temperature       0.021069             0.889160             1.000000
# average temperature       0.022611             0.977544             0.965623
# precipitation            -0.034632             0.221113             0.102974
# snow fall                -0.009821            -0.094917            -0.135048
# snow depth                0.014713             0.202724             0.228111
#
#                           average temperature  precipitation  snow fall  \
# Trip Duration                       -0.037542      -0.007900  -0.003725
# Start Station ID                    -0.010718      -0.006927  -0.020095
# Start Station Latitude              -0.003576       0.008255  -0.004970
# Start Station Longtitude             0.029320      -0.010111   0.003085
# End Station ID                       0.005484      -0.000807  -0.024681
# End Station Latitude                -0.015678      -0.003269   0.009392
# End Station Longtitude               0.018208      -0.013085  -0.005575
# Bike ID                             -0.009104       0.012072   0.018574
# Birth Year                           0.003990      -0.005175   0.004706
# Gender                               0.022611      -0.034632  -0.009821
# maximum temperature                  0.977544       0.221113  -0.094917
# minimum temperature                  0.965623       0.102974  -0.135048
# average temperature                  1.000000       0.173029  -0.116112
# precipitation                        0.173029       1.000000   0.254843
# snow fall                           -0.116112       0.254843   1.000000
# snow depth                           0.220211       0.001066   0.278514
#
#                           snow depth
# Trip Duration              -0.005250
# Start Station ID           -0.017990
# Start Station Latitude      0.010520
# Start Station Longtitude    0.023392
# End Station ID             -0.004568
# End Station Latitude        0.005592
# End Station Longtitude      0.008409
# Bike ID                     0.013145
# Birth Year                 -0.008337
# Gender                      0.014713
# maximum temperature         0.202724
# minimum temperature         0.228111
# average temperature         0.220211
# precipitation               0.001066
# snow fall                   0.278514
# snow depth                  1.000000

# %% [markdown]
# Check most popular hours to take a (long) trip:

# %%
(full_df
     .groupby(f.hour('Start Time').alias('Hour'))
     .agg(f.sum('Trip Duration').alias('Total Trip Duration'),
          f.count(f.lit(1)).alias('Total Trips'))
     .sort(f.desc('Total Trip Duration'))
).toPandas()
# Out:
#     Hour  Total Trip Duration  Total Trips
# 0      8              2644987         1168
# 1     16              2384178          434
# 2      7              2379639          639
# 3     18               486769          792
# 4     17               427550          686
# 5     10               423564          345
# 6     14               381342          332
# 7     11               375820          341
# 8     12               374920          343
# 9     15               317541          343
# 10    13               279178          360
# 11     9               269415          528
# 12    19               247785          557
# 13    20               164779          382
# 14    22               101417          199
# 15    23                95482          101
# 16    21                95152          248
# 17     6                94366          236
# 18     0                63700           75
# 19     4                55799           13
# 20     1                38478           39
# 21     5                34105           62
# 22     2                 9726           17
# 23     3                 3397           10

# %% [markdown]
# Check the most popular days of the week to take a (long) trip:
# * 1 - Sunday
# * 2 - Monday
# * 3 - Tuesday
# * 4 - Wednesday
# * 5 - Thursday
# * 6 - Friday
# * 7 - Saturday

# %%
(full_df
     .groupby(f.dayofweek('Start Day').alias('Day of Week'))
     .agg(f.sum('Trip Duration').alias('Total Trip Duration'),
          f.count(f.lit(1)).alias('Total Trips'))
     .sort(f.desc('Total Trip Duration'))
).toPandas()
# Out:
#    Day of Week  Total Trip Duration  Total Trips
# 0            6              6871518         1101
# 1            1              1066491         1014
# 2            2              1001266         1591
# 3            4               811267         1095
# 4            5               688964         1358
# 5            7               675221          866
# 6            3               634362         1225

# %% [markdown]
# Check the days of the month with longest/most trips:

# %%
(full_df
     .groupby(f.dayofmonth('Start Day').alias('Day of Month'))
     .agg(f.sum('Trip Duration').alias('Total Trip Duration'),
          f.count(f.lit(1)).alias('Total Trips'))
     .sort(f.desc('Total Trip Duration'))
).toPandas()
# Out:
#     Day of Month  Total Trip Duration  Total Trips
# 0             12              6426900          249
# 1             28               598657          417
# 2             17               452647          353
# 3             20               355429          342
# 4             22               342570          437
# 5             29               280572          405
# 6             21               269286          304
# 7             25               206130          372
# 8             18               198425          340
# 9             16               190727          222
# 10             1               188602          355
# 11             2               179269          411
# 12            19               172932          330
# 13             4               169178          378
# 14            26               164127          345
# 15             7               161228          233
# 16            27               157479          237
# 17             3               153617          267
# 18             8               137825          303
# 19            10               137544          305
# 20             9               134866          297
# 21             6               134466          224
# 22            23               129500          295
# 23            11               115231          268
# 24             5               107559          177
# 25            24                67459          170
# 26            15                51697           91
# 27            14                37320           60
# 28            13                27847           63
